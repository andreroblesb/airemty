# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\REPO\Tec2025\Multivariados\Etapa2\base_final_imputada_por_zona.csv")
df.head(10)
# Out:
#      Zona           date       SO2  RAINF       WSR    WDR
# 0  Centro  1/1/2021 0:00 -0.307692    0.0 -0.581818  336.0
# 1  Centro  1/1/2021 1:00 -0.269231    0.0  0.181818   78.0
# 2  Centro  1/1/2021 2:00 -0.269231    0.0 -0.381818   47.0
# 3  Centro  1/1/2021 3:00 -0.153846    0.0 -0.309091  349.0
# 4  Centro  1/1/2021 4:00 -0.192308    0.0 -0.672727  358.0
# 5  Centro  1/1/2021 5:00 -0.153846    0.0 -0.709091   19.0
# 6  Centro  1/1/2021 6:00 -0.230769    0.0 -0.818182    8.0
# 7  Centro  1/1/2021 7:00 -0.192308    0.0 -0.709091   16.0
# 8  Centro  1/1/2021 8:00 -0.269231    0.0 -0.400000   14.0
# 9  Centro  1/1/2021 9:00 -0.269231    0.0 -0.436364   10.0

# %% [markdown]
# # Análisis Estadístico Descriptivo

# %% [markdown]
# Análisis Descriptivo de Dióxido de Azufre

# %%
df.groupby("Zona")["SO2"].describe()
# Out:
#              count      mean       std       min       25%       50%  \
# Zona
# Centro     39408.0  0.258487  1.082291 -1.346154 -0.423077  0.038462
# Noreste    38101.0  0.279644  1.282831 -1.375000 -0.416667  0.041667
# Noreste2   39408.0  0.411697  1.450374 -0.942857 -0.285714  0.000000
# Noreste3   38540.0  0.642496  3.307389 -1.315789 -0.263158  0.000000
# Noroeste   39408.0  0.305429  1.060992 -1.156250 -0.343750  0.000000
# Noroeste2  39408.0  0.190958  1.183172 -1.404762 -0.404762 -0.071429
# Noroeste3  21722.0  0.374989  1.684143 -1.736842 -0.368421  0.000000
# Norte      38119.0  0.321223  1.199944 -1.217391 -0.347826  0.000000
# Norte2     36327.0  0.234984  1.134265 -1.476563 -0.333333  0.000000
# Sur        38064.0  0.155012  1.171124 -1.714286 -0.500000  0.000000
# Sureste    39408.0  0.051511  0.840566 -1.176724 -0.452586 -0.125000
# Sureste2   39408.0  0.420898  1.931312 -1.250000 -0.392857 -0.035714
# ...

# %%
df.groupby("Zona")["RAINF"].describe()
# Out:
#              count          mean           std  min  25%  50%  75%  \
# Zona
# Centro     39408.0      0.006077  6.308513e-01  0.0  0.0  0.0  0.0
# Noreste    39408.0      0.001191  4.526741e-02  0.0  0.0  0.0  0.0
# Noreste2   39408.0      0.020116  7.310486e-01  0.0  0.0  0.0  0.0
# Noreste3   39408.0      0.063216  9.018796e-01  0.0  0.0  0.0  0.0
# Noroeste   39408.0      0.020430  4.842134e-01  0.0  0.0  0.0  0.0
# Noroeste2  39408.0      0.003040  1.541162e-01  0.0  0.0  0.0  0.0
# Noroeste3  22631.0      0.000000  0.000000e+00  0.0  0.0  0.0  0.0
# Norte      36511.0      0.000223  1.233169e-02  0.0  0.0  0.0  0.0
# Norte2     39408.0      0.004977  1.596071e-01  0.0  0.0  0.0  0.0
# Sur        39408.0      0.001316  2.766988e-02  0.0  0.0  0.0  0.0
# Sureste    39408.0      0.123717  1.423130e+00  0.0  0.0  0.0  0.0
# Sureste2   37152.0      0.049930  3.860681e+00  0.0  0.0  0.0  0.0
# Sureste3   39408.0      0.001261  3.295443e-02  0.0  0.0  0.0  0.0
# ...

# %%
df.groupby("Zona")["WSR"].describe()
# Out:
#              count      mean       std       min       25%       50%  \
# Zona
# Centro     39408.0  0.129876  0.708237 -1.236364 -0.436364  0.072727
# Noreste    39408.0  0.118118  0.663561 -1.085714 -0.385714  0.057143
# Noreste2   38104.0  0.273857  1.189167 -1.161765 -0.352941  0.088235
# Noreste3   39408.0  0.089771  0.657574 -0.807229 -0.469880  0.000000
# Noroeste   39408.0  0.180104  0.752005 -0.933333 -0.386667  0.000000
# Noroeste2  39408.0  0.093477  0.600511 -1.011111 -0.411111  0.044444
# Noroeste3  21332.0  0.152636  1.357794 -1.507937 -0.523810  0.000000
# Norte      37279.0  0.166377  0.694433 -1.096774 -0.370968  0.048387
# Norte2     39408.0  0.102328  0.803021 -1.761905 -0.428571  0.023810
# Sur        39408.0  0.325254  0.875000 -0.946429 -0.232143  0.160714
# Sureste    39408.0  0.061022  0.627116 -1.094118 -0.447059 -0.035294
# Sureste2   39408.0  0.124876  0.629813 -0.718750 -0.453125 -0.015625
# ...

# %%
df.groupby("Zona")["WDR"].describe()
# Out:
#              count        mean         std     min    25%    50%         75%  \
# Zona
# Centro     39408.0  108.183760   89.849616     1.0   49.0   75.0  123.000000
# Noreste    39408.0  137.200898   80.198534     1.0   88.0  136.0  160.000000
# Noreste2   37876.0  199.825757  106.747004 -9999.0  127.0  164.0  296.000000
# Noreste3   39408.0  154.356402   92.151542     1.0   87.0  114.0  250.000000
# Noroeste   39408.0  152.762383  100.940384     1.0   73.0  116.0  250.000000
# Noroeste2  39408.0  131.305739   86.917935     1.0   90.0  104.0  127.000000
# Noroeste3  22631.0   96.503181   91.875118     1.0   33.0   61.0  106.000000
# Norte      37279.0   87.070294  219.431724 -9999.0   21.0   84.0  139.000000
# Norte2     39408.0  100.960604   86.860092     1.0   44.0   80.0  110.000000
# Sur        38566.0  183.677899   97.885511     1.0  133.0  160.0  271.746897
# Sureste    38849.0  146.571293   93.606026     1.0   85.0  109.0  219.000000
# ...
